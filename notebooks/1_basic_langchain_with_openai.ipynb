# %% [markdown]
# ## Load Env Variable

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# ## Connect with Google Gemini Model

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm=ChatGoogleGenerativeAI(model="gemini-3.5-flash-lite")
response=llm.invoke("What is the capital of France?")
response
# Out:
# AIMessage(content=[{'type': 'text', 'text': 'The capital of France is Paris.', 'extras': {'signature': 'El4KXAERTTIPxVsj2Nbrz1ZdMgUjEQUGQDPcm7CtlgULJ/6Yh7e6nfhnUYIQ5c0rue54tqL8/AeKvdWomAIEsTCO/emmgx4J7if92+FkLmu2ElMwJx6rttucd2brW4fZ'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--01a0a093-f7ff-75c0-99e6-93cd34ded87a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 8, 'output_tokens': 7, 'total_tokens': 15, 'input_token_details': {'cache_read': 0}})

# %%
response.content
# Out:
# [{'type': 'text',
#   'text': 'The capital of France is Paris.',
#   'extras': {'signature': 'El4KXAERTTIPxVsj2Nbrz1ZdMgUjEQUGQDPcm7CtlgULJ/6Yh7e6nfhnUYIQ5c0rue54tqL8/AeKvdWomAIEsTCO/emmgx4J7if92+FkLmu2ElMwJx6rttucd2brW4fZ'}}]

# %% [markdown]
# ## Static Prompt

# %%
prompt=[
    ("system", "You are president of France"),
    ("user","What is the capital of your country?")
]
result=llm.invoke(prompt)
result.content
# Out:
# [{'type': 'text',
#   'text': 'The capital of France is Paris. *Bien sûr !*',
#   'extras': {'signature': 'El4KXAERTTIP/KTdT5k29UPoKF9OWS4/BQMV2vVK+RRZvGk9Gy2A4ZWpHPOI8HQTvZkRHsZcd6eC7kj7WNQUALv4FkfAZ+6CyaHLc2yz7YsUOwAh/zAJxJJFl/yFAVce'}}]
