# %% [markdown]
# ## Load Env Variable

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# ## Connect with Google Gemini Model

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm=ChatGoogleGenerativeAI(model="gemini-3.5-flash-lite")
response=llm.invoke("What is the capital of France?")
response
# Out:
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# AIMessage(content=[{'type': 'text', 'text': 'The capital of France is Paris.', 'extras': {'signature': 'El4KXAFpFH0T2y2N1DafRj13CUb+YZNnV6/GJ9ve1e+GJAvWlgaID2K4Oa2QCkY4/e1yhwGNUkt3L2HXeA3/I9tH6FroWcWKhtyLuddrJCPwWpEO9MPjaDNWFisU86Kr'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--01a0bf22-17cc-7c82-a65f-508a625c6369-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 8, 'output_tokens': 7, 'total_tokens': 15, 'input_token_details': {'cache_read': 0}})

# %%
response.content
# Out:
# [{'type': 'text',
#   'text': 'The capital of France is Paris.',
#   'extras': {'signature': 'El4KXAFpFH0T2y2N1DafRj13CUb+YZNnV6/GJ9ve1e+GJAvWlgaID2K4Oa2QCkY4/e1yhwGNUkt3L2HXeA3/I9tH6FroWcWKhtyLuddrJCPwWpEO9MPjaDNWFisU86Kr'}}]

# %% [markdown]
# ## Static Prompt

# %%
prompt=[
    ("system", "You are president of France"),
    ("user","What is the capital of your country?")
]
result=llm.invoke(prompt)
result.content
# Out:
# [{'type': 'text',
#   'text': 'The capital of France is Paris—a magnificent city, the heart of our culture, history, and the republic.',
#   'extras': {'signature': 'El4KXAFpFH0TrXaWKsQJEKKzTHUsWxCZlvuqK2oDX3xA8SGNILu7ERHnt8ZxAwKWrp2yaO3vtuPW1HyPNIw2SG9b0rNuyT5gUv3jUpHndlTWfUhE0ANXct9g+dydToYI'}}]

# %% [markdown]
# ## Manage History

# %%
history=[]
while True:
    query=input("User:")
    if query.lower()  in ["exit", "quit"]:
        break
    history.append({"role": "user", "content": query})
    # print("User:",query)
    res=llm.invoke(history)
    history.append({"role": "ai", "content": res.content[0]["text"]})
    print("AI:",res.content[0]["text"])
# Out:
# User: hii
# AI: [{'type': 'text', 'text': 'Hii there! How can I help you today?', 'extras': {'signature': 'El4KXAFpFH0TTmjogiSlWd2oSWrURMys6JtbxYR9qONDDTR+5mFmqQe0GH7Gx1iztwd6iXM4G7VE+MtRug0E+uSCCuarxVCOeE1r9w45UU9BUzGRdD/5ZmLZeyrzrMfj'}}]
# User: my name is ulka
# AI: [{'type': 'text', 'text': 'Nice to meet you, Ulka! How is your day going?', 'extras': {'signature': 'El4KXAFpFH0TbDvjGCRbpooCzaO83PMh/wPrq0rUJGg1kGnskPGbhRNgOuPC2HTwygKUpRzcKW++GamkPqMCZz2SRwVOEpbUqWOGSsMElY7NYi2xXTxpTHL3ZUlCemBN'}}]
# User: what is my name
# AI: [{'type': 'text', 'text': 'Your name is Ulka!', 'extras': {'signature': 'El4KXAFpFH0TB03ufLKmoS4vH3FO12c26TPALkH37p+zmaNp7gmS78U9T9OzHzDBaDJ0S8IH5GTw73eB7lsEuvhyUQRVMj3EYNfwcCZDL33jzmsAhmWIZ+BMla4krAR1'}}]
# User: now tell me
# AI: [{'type': 'text', 'text': 'Tell you what, Ulka? Did you have a specific question or something else on your mind?', 'extras': {'signature': 'El4KXAFpFH0T60Q8S0b0WgVT/mpAqU0xMjPqo/fsAgpOB4kzGdhbchASIga7XiA0be4gDEhTYfhFgGJvjUEVyuIKMgIJ3cDC61uKYinBGfEWSGCx3JQZjTPxSv4zZuMc'}}]
